# %% [markdown]
# # Web scraping part 2: craigslist

# %% [markdown]
# ## Lecture objectives
#
# 1. More practice with scraping web pages and parsing text
# 2. Learn how to handle errors ("exceptions") gracefully
# 3. More pratice with `pandas` and plotting

# %% [markdown]
# ## Example: Scraping craigslist data
# Craiglist provides a wealth of information on apartment rentals and other types of housing, as you can read about in the [Boeing and Waddell paper](https://journals.sagepub.com/doi/abs/10.1177/0739456X16664789). But short of clicking through lots of links, how do we access it?
#
# As with any scraping project, the first step is to get an example web page, and see if we can reverse-engineer the structure.
#
# One option is to parse each detailed post, with information on parking, desired qualities of roommates, etc. But a lot of information is actually in the [list of posts](https://losangeles.craigslist.org/search/lac/hhh).

# %% [markdown]
# **Option 1**. You can download the most recent posts yourself.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://losangeles.craigslist.org/search/lac/hhh'
r = requests.get(url)

soup = BeautifulSoup(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="central LA housing - craigslist" property="og:title"/>
#   <meta content="central LA housing - craigslist" name="description"/>
#   <meta content="central LA housing - craigslist" property="og:description"/>
#   <meta content="https://losangeles.craigslist.org/search/lac/hhh" property="og:url"/>
#   <meta content="true" name="smartbanner:api"/>
#   <meta content="the craigslist app" name="smartbanner:title"/>
#   <meta content="what's old is new" name="smartbanner:author"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-google"/>
#   <meta content="view" name="smartbanner:button"/>
#   <meta content="close" name="smartbanner:close-label"/>
#   <meta content="https://apps.apple.com/us/app/craigslist/id1336642410" name="smartbanner:button-url-apple"/>
#   <meta content="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile" name="smartbanner:button-url-google"/>
#   <meta content="android,ios" name="smartbanner:enabled-platforms"/>
#   <title>
#    central LA housing - craigslist
#   </title>
#   <link href="https://losangeles.craigslist.org/search/lac/hhh" rel="canonical"/>
#   <link href="https://losangeles.craigslist.org/search/lac/hhh?s=120" rel="next"/>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"losangeles.craigslist.org","@id":"https://losangeles.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"central LA","@id":"https://losangeles.craigslist.org/lac/"},"position":2,"@type":"ListItem"},{"item":{"name":"housing","@id":"https://losangeles.craigslist.org/search/lac/hhh"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <style type="text/css">
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js,
#         #unsupported-browser {
#             position: fixed;
#             z-index: 10000;
#
#             top: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         #no-js p,
#         #unsupported-browser p {
#             color: black;
#             background-color: #FA8787;
#             opacity: 0.8;
#             text-align: center;
#             margin: 0;
#             border: 0;
#             padding: 1em;
#         }
#
#         #unsupported-browser {
#             display: none;
#         }
#
#         .unsupported-browser #unsupported-browser {
#             display: block;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#             font-size: 2em;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#   </style>
#   <script src="https://www.craigslist.org/static/www/4aa05aa5430548804d0c2c9dc3363f638c857c1f.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'browsePostings',
#              {
# areaCountry: "US",
# areaID: "7",
# areaRegion: "CA",
# catAbb: "hhh",
# categoryStr: "hhh",
# countOfTotalText: "image {count} of {total}",
# currencySymbol: "&#x0024;",
# defaultLocale: "en_US",
# defaultView: "grid",
# expiredFavIDs: null,
# hubLinkText: null,
# hubName: null,
# imageConfig: {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}},
# lessInfoText: "less info",
# locParams: null,
# locString: "",
# maptileBaseUrl: "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png",
# maxResults: 3000,
# noImageText: "no image",
# pID: null,
# postalLat: null,
# postalLon: null,
# purveyorCategories: null,
# purveyorStr: "",
# searchDistance: null,
# sectionAbb: "hhh",
# sectionBase: "hhh",
# showInfoText: "show info",
# showMapTabs: 1,
# showingBanished: 0,
# showingFavorites: 0,
# starHint: "save this post in your favorites list",
# subarea: "lac",
# zoomToPosting: null
# },
#              0
#          );
#   </script>
#  </head>
#  <body class="no-js show-curtain opaque search has-map">
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text unrecoverable">
#      There was an error loading the page; please try to
#      <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#       refresh the page.
#      </a>
#     </div>
#     <div class="text message">
#     </div>
#    </div>
#   </div>
#   <noscript id="no-js">
#    <div>
#     <p>
#      We've detected that JavaScript is not enabled in your browser.
#     </p>
#     <p>
#      You must enable JavaScript to use craigslist.
#     </p>
#    </div>
#   </noscript>
#   <div id="unsupported-browser">
#    <p>
#     We've detected you are using a browser that is missing critical features.
#    </p>
#    <p>
#     Please visit craigslist from a modern browser.
#    </p>
#   </div>
#   <section class="page-container" data-areaid="7" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="https://losangeles.craigslist.org/lac/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/lac/hhh" class="breadcrumbs-form" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           los angeles
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="losangeles">
#           los angeles
#          </option>
#          <option value="bakersfield">
#           bakersfield
#          </option>
#          <option value="fresno">
#           fresno
#          </option>
#          <option value="hanford">
#           hanford
#          </option>
#          <option value="imperial">
#           imperial co
#          </option>
#          <option value="inlandempire">
#           inland empire
#          </option>
#          <option value="lasvegas">
#           las vegas
#          </option>
#          <option value="orangecounty">
#           orange co
#          </option>
#          <option value="palmsprings">
#           palm springs
#          </option>
#          <option value="sandiego">
#           san diego
#          </option>
#          <option value="slo">
#           san luis obispo
#          </option>
#          <option value="santabarbara">
#           santa barbara
#          </option>
#          <option value="santamaria">
#           santa maria
#          </option>
#          <option value="ventura">
#           ventura
#          </option>
#          <option value="visalia">
#           visalia-tulare
#          </option>
#          <option value="yuma">
#           yuma
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb subarea">
#         <select id="subArea" name="subArea">
#          <option value="">
#           all los angeles
#          </option>
#          <option value="sfv">
#           SF valley
#          </option>
#          <option value="ant">
#           antelope valley
#          </option>
#          <option selected="" value="lac">
#           central LA
#          </option>
#          <option value="lgb">
#           long beach
#          </option>
#          <option value="sgv">
#           san gabriel valley
#          </option>
#          <option value="wst">
#           westside-southbay
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option selected="" value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="hhh">
#           all
#          </option>
#          <option value="apa">
#           apartments / housing for rent
#          </option>
#          <option value="swp">
#           housing swap
#          </option>
#          <option value="off">
#           office &amp; commercial
#          </option>
#          <option value="prk">
#           parking &amp; storage
#          </option>
#          <option value="reb">
#           real estate - by broker
#          </option>
#          <option value="reo">
#           real estate - by owner
#          </option>
#          <option value="roo">
#           rooms &amp; shares
#          </option>
#          <option value="sub">
#           sublets &amp; temporary
#          </option>
#          <option value="vac">
#           vacation rentals
#          </option>
#          <option value="hou">
#           wanted: apts
#          </option>
#          <option value="rew">
#           wanted: real estate
#          </option>
#          <option value="sha">
#           wanted: room/share
#          </option>
#          <option value="sbw">
#           wanted: sublet/temp
#          </option>
#         </select>
#         <span class="no-js">
#          housing
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/lax">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <div class="to-banish-page">
#         <a class="to-banish-page-link" href="#">
#          <span aria-hidden="true" class="icon icon-trash red">
#          </span>
#          <span class="banished_count">
#           0
#          </span>
#          <span class="discards-label">
#           hidden
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="https://losangeles.craigslist.org/lac/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       central LA            &gt;
#
# housing
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/lac/hhh" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search housing" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Flosangeles%2Ecraigslist%2Eorg%2Fsearch%2Flac%2Fhhh" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="https://losangeles.craigslist.org/search/lac/hhh" title="clear all search parameters">
#        housing
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <ul class="maincats">
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 12 categories
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 12 categories
#          </span>
#          <span class="count">
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="apa" id="cat_apa" name="cat_id" type="checkbox" value="1"/>
#          <a class="category" href="/search/lac/apa">
#           apartments / housing for rent
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="swp" id="cat_swp" name="cat_id" type="checkbox" value="65"/>
#          <a class="category" href="/search/lac/swp">
#           housing swap
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="off" id="cat_off" name="cat_id" type="checkbox" value="40"/>
#          <a class="category" href="/search/lac/off">
#           office &amp; commercial
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="prk" id="cat_prk" name="cat_id" type="checkbox" value="41"/>
#          <a class="category" href="/search/lac/prk">
#           parking &amp; storage
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rea" id="cat_rea" name="cat_id" type="checkbox" value="143,144"/>
#          <a class="category" href="/search/lac/rea">
#           real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="roo" id="cat_roo" name="cat_id" type="checkbox" value="18"/>
#          <a class="category" href="/search/lac/roo">
#           rooms &amp; shares
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sub" id="cat_sub" name="cat_id" type="checkbox" value="39"/>
#          <a class="category" href="/search/lac/sub">
#           sublets &amp; temporary
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vac" id="cat_vac" name="cat_id" type="checkbox" value="99"/>
#          <a class="category" href="/search/lac/vac">
#           vacation rentals
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hou" id="cat_hou" name="cat_id" type="checkbox" value="2"/>
#          <a class="category" href="/search/lac/hou">
#           wanted: apts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rew" id="cat_rew" name="cat_id" type="checkbox" value="121"/>
#          <a class="category" href="/search/lac/rew">
#           wanted: real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sha" id="cat_sha" name="cat_id" type="checkbox" value="19"/>
#          <a class="category" href="/search/lac/sha">
#           wanted: room/share
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sbw" id="cat_sbw" name="cat_id" type="checkbox" value="58"/>
#          <a class="category" href="/search/lac/sbw">
#           wanted: sublet/temp
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <div class="selectall js-only checked">
#           <label>
#            <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#            <span class="all linklike">
#             select all
#            </span>
#           </label>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div class="searchgroup" id="basic-bools">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from location
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value="">
#          <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#          <span class="icon icon-locate">
#          </span>
#         </input>
#        </div>
#        <div class="searchgroup minmax price" id="price">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bedrooms
#         </span>
#         <select class="autosubmit" name="min_bedrooms">
#          <option value="">
#           min
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bedrooms">
#          <option value="">
#           max
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bathrooms
#         </span>
#         <select class="autosubmit" name="min_bathrooms">
#          <option value="">
#           min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bathrooms">
#          <option value="">
#           max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax" id="">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          availability
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option value="0">
#           all dates
#          </option>
#          <option value="1">
#           within 30 days
#          </option>
#          <option value="2">
#           beyond 30 days
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup search-group-checkbox">
#         <label class="private_room">
#          <input class="autosubmit" name="private_room" type="checkbox" value="1">
#           private room
#          </input>
#         </label>
#         <br/>
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#           cats ok
#          </input>
#         </label>
#         <br/>
#         <label class="private_bath">
#          <input class="autosubmit" name="private_bath" type="checkbox" value="1">
#           private bath
#          </input>
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#           dogs ok
#          </input>
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1">
#           furnished
#          </input>
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#           no smoking
#          </input>
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#           wheelchair access
#          </input>
#         </label>
#         <br/>
#         <label class="airconditioning">
#          <input class="autosubmit" name="airconditioning" type="checkbox" value="1">
#           air conditioning
#          </input>
#         </label>
#         <br/>
#         <label class="ev_charging">
#          <input class="autosubmit" name="ev_charging" type="checkbox" value="1">
#           EV charging
#          </input>
#         </label>
#         <br/>
#         <label class="application_fee">
#          <input class="autosubmit" name="application_fee" type="checkbox" value="1">
#           no application fee
#          </input>
#         </label>
#         <br/>
#         <label class="broker_fee">
#          <input class="autosubmit" name="broker_fee" type="checkbox" value="1">
#           no broker fee
#          </input>
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup search-group-multi_checkbox">
#         <div class="search-attribute hide-list" data-attr="housing_type">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           housing type
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_1" name="housing_type" type="checkbox" value="1">
#              apartment
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_2" name="housing_type" type="checkbox" value="2">
#              condo
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_3" name="housing_type" type="checkbox" value="3">
#              cottage/cabin
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_4" name="housing_type" type="checkbox" value="4">
#              duplex
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_5" name="housing_type" type="checkbox" value="5">
#              flat
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_6" name="housing_type" type="checkbox" value="6">
#              house
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_7" name="housing_type" type="checkbox" value="7">
#              in-law
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_8" name="housing_type" type="checkbox" value="8">
#              loft
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_9" name="housing_type" type="checkbox" value="9">
#              townhouse
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_10" name="housing_type" type="checkbox" value="10">
#              manufactured
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_11" name="housing_type" type="checkbox" value="11">
#              assisted living
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_12" name="housing_type" type="checkbox" value="12"/>
#             land
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           laundry
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1"/>
#             w/d in unit
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4"/>
#             w/d hookups
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2"/>
#             laundry in bldg
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             laundry on site
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             no laundry on site
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           parking
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             carport
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             attached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             detached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             off-street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             valet parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             no parking
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="rent_period">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           rent period
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_1" name="rent_period" type="checkbox" value="1"/>
#             daily
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_2" name="rent_period" type="checkbox" value="2"/>
#             weekly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_3" name="rent_period" type="checkbox" value="3"/>
#             monthly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_4" name="rent_period" type="checkbox" value="4"/>
#             yearly
#            </label>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <div class="searchfieldlabel">
#          open house date
#         </div>
#         <select class="autosubmit" id="sale_date" name="sale_date">
#          <option>
#           all dates
#          </option>
#          <option value="2022-03-31">
#           mar 31 - today
#          </option>
#          <option value="2022-04-01">
#           apr 1 - tomorrow
#          </option>
#          <option value="2022-04-02">
#           apr 2 - saturday
#          </option>
#          <option value="2022-04-03">
#           apr 3 - sunday
#          </option>
#          <option value="2022-04-04">
#           apr 4 - monday
#          </option>
#          <option value="2022-04-05">
#           apr 5 - tuesday
#          </option>
#          <option value="2022-04-06">
#           apr 6 - wednesday
#          </option>
#          <option value="2022-04-07">
#           apr 7 - thursday
#          </option>
#          <option value="2022-04-08">
#           apr 8 - friday
#          </option>
#          <option value="2022-04-09">
#           apr 9 - saturday
#          </option>
#          <option value="2022-04-10">
#           apr 10 - sunday
#          </option>
#          <option value="2022-04-11">
#           apr 11 - monday
#          </option>
#          <option value="2022-04-12">
#           apr 12 - tuesday
#          </option>
#          <option value="2022-04-13">
#           apr 13 - wednesday
#          </option>
#          <option value="2022-04-14">
#           apr 14 - thursday
#          </option>
#          <option value="2022-04-15">
#           apr 15 - friday
#          </option>
#          <option value="2022-04-16">
#           apr 16 - saturday
#          </option>
#          <option value="2022-04-17">
#           apr 17 - sunday
#          </option>
#          <option value="2022-04-18">
#           apr 18 - monday
#          </option>
#          <option value="2022-04-19">
#           apr 19 - tuesday
#          </option>
#          <option value="2022-04-20">
#           apr 20 - wednesday
#          </option>
#          <option value="2022-04-21">
#           apr 21 - thursday
#          </option>
#          <option value="2022-04-22">
#           apr 22 - friday
#          </option>
#          <option value="2022-04-23">
#           apr 23 - saturday
#          </option>
#          <option value="2022-04-24">
#           apr 24 - sunday
#          </option>
#          <option value="2022-04-25">
#           apr 25 - monday
#          </option>
#          <option value="2022-04-26">
#           apr 26 - tuesday
#          </option>
#          <option value="2022-04-27">
#           apr 27 - wednesday
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="https://losangeles.craigslist.org/search/lac/hhh" title="clear all search parameters">
#          reset
#         </a>
#         <button class="searchlink linklike" type="submit">
#          update search
#         </button>
#        </div>
#        <aside class="tsb">
#         <ul>
#          <li>
#           <a href="https://www.craigslist.org/about/FHA">
#            fair housing
#           </a>
#           <li>
#            <a href="https://www.craigslist.org/about/scams">
#             avoiding scams
#            </a>
#           </li>
#          </li>
#         </ul>
#        </aside>
#       </input>
#      </div>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="show results in a list">
#           <span class="view-list icon">
#           </span>
#           list
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
#           <span class="view-thumb icon">
#           </span>
#           thumb
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
#           <span class="view-gallery icon">
#           </span>
#           gallery
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="map" id="mapview" title="show results on a map">
#           <span class="view-map icon">
#           </span>
#           map
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="upcoming" href="/search/lac/hhh?sort=upcoming&amp;" title="show upcoming open houses">
#           upcoming
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="true" class="dropdown-item mode sel">
#          <a data-selection="date" href="/search/lac/hhh?sort=date&amp;" title="show newest matches first">
#           newest
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="priceasc" href="/search/lac/hhh?sort=priceasc&amp;" title="sort by price, lowest to highest">
#           price ↑
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="pricedsc" href="/search/lac/hhh?sort=pricedsc&amp;" title="sort by price, highest to lowest">
#           price ↓
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <div class="content" id="sortable-results">
#      <section class="favlistsection">
#       <section class="favlistinfo">
#       </section>
#       <section class="banishlistinfo">
#       </section>
#      </section>
#      <div class="open-map-view-button">
#       <span>
#        see in map view
#       </span>
#      </div>
#      <div data-arealat="34.052200" data-arealon="-118.242996" id="mapcontainer">
#       <div id="update-search-area-button">
#       </div>
#       <div id="noresult-overlay">
#       </div>
#       <div id="noresult-text">
#        <span class="message">
#         No mappable items found
#        </span>
#       </div>
#       <div class="loading" id="map">
#        <div class="close-full-screen-map-mode-button">
#         close fullscreen
#        </div>
#       </div>
#      </div>
#      <ul class="rows" id="search-results">
#       <li class="result-row" data-pid="7463734231">
#        <a class="result-image gallery" data-ids="3:00M0M_abOucMhg6UIz_0iA0dW,3:00d0d_le09Ki8EAaMz_05a03r,3:00l0l_j4o6nHxsnufz_05a03r,3:00404_dmCUVhooHmNz_05a03r,3:00b0b_k1pkof2aEk6z_05a03r,3:00e0e_aZRBBdupVkAz_05a03r,3:00c0c_jTElxeZubBpz_05a03r,3:00x0x_3WZAeHZdNWZz_05a03r,3:00L0L_39yxSep5Stwz_0c60c6" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dtla-luxury-living/7463734231.html">
#         <span class="result-price">
#          $3,025
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 15:48" title="Thu 31 Mar 03:48:20 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7463734231" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dtla-luxury-living/7463734231.html" id="postid_7463734231">
#           DTLA Luxury Living Perfected! Come to The Orsini &amp; Have it All!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $3,025
#          </span>
#          <span class="housing">
#           2br -
#                     946ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (550 N. Figueroa Street , Los Angeles, CA)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7465420541">
#        <a class="result-image gallery" data-ids="3:00t0t_g3PZmhwn6Tlz_05O07K,3:00t0t_l8O0oMXL7eQz_03S05a,3:00M0M_4DxNYavcn7ez_05O07K,3:01616_dD5n7Lelejiz_05O07K,3:00d0d_1XAs1F9LgJGz_05O07K,3:00L0L_bzCc8mHBh5Zz_03S05a,3:00P0P_8vUaZ1nslKDz_03S05a,3:00n0n_8aao2poIR33z_03S05a,3:00z0z_8amrxo5AiKmz_03S05a,3:01515_gZK4uyoDjKjz_03S05a,3:00404_fQgIXITRz5Kz_05O07K,3:00C0C_9TAzIgqe98Qz_03S05a,3:00O0O_a5UNTi6NVJ9z_03S05a,3:01515_iFgG0eeEiaEz_03S05a,3:00l0l_IF5PjM7rC3z_03S05a,3:00o0o_73HIAkGygMPz_05O07K,3:00J0J_aBq3ePvyh1Qz_03S05a,3:00N0N_jIpV8pJTGAxz_03S05a,3:00303_9MYVPfwZfG4z_03S05a,3:00R0R_OvQBUwkXWGz_05O07K,3:00g0g_jc5NtJidpiWz_05O07K,3:00i0i_3h5JvD2vy33z_05O07K,3:01111_8oLwWCPlkIAz_03S05a,3:00h0h_1TnnS17RwCtz_05O07K" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-amazing-br-heart-of/7465420541.html">
#         <span class="result-price">
#          $4,205
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 15:47" title="Thu 31 Mar 03:47:59 PM">
# ...
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7465400226">
#        <a class="result-image gallery" data-ids="3:00O0O_jLGVcH7TEvAz_0ak07K,3:00c0c_7OtVJLXXxYzz_0ak07K,3:00101_c8nMCbwvFTWz_07K0ak,3:00N0N_lcMxY1bBkfPz_0gw0co,3:00p0p_dWgTaAkZK4Mz_07K0ak" href="https://losangeles.craigslist.org/lac/apa/d/valley-village-higher-quality-of-living/7465400226.html">
#         <span class="result-price">
#          $2,795
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:55" title="Thu 31 Mar 02:55:04 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7465400226" href="https://losangeles.craigslist.org/lac/apa/d/valley-village-higher-quality-of-living/7465400226.html" id="postid_7465400226">
#           A Higher Quality of Living. Radford Apt  SPECIAL OFFER call now!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $2,795
#          </span>
#          <span class="housing">
#           2br -
#                     975ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Valley Village)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7465400109" data-repost-of="7158703829">
#        <a class="result-image gallery" data-ids="3:00I0I_8tQOVt8wUVjz_0CI0t2,3:00q0q_jnvFAP1H3ztz_0CI0t2,3:00d0d_kXmXlugm7bWz_0CI0t2,3:00G0G_9TRctaLqf5bz_0CI0t2,3:00909_osNHMY28zCz_0CI0qM,3:00a0a_7ck2ivFht9Jz_0CI0t2,3:00Y0Y_1nxKF2pWaMSz_0CI0t2,3:00m0m_87JV6y5Z34z_0CI0t2,3:00202_gr9RvsxwPvLz_0CI0t2,3:01010_ilfdkcv7aiaz_0CI0t2,3:00T0T_3pSSXlEQtIyz_0lM0t2,3:00X0X_lL1KlhCv1LRz_0CI0t2" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-pets-ok-amazing/7465400109.html">
#         <span class="result-price">
#          $1,325
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:54" title="Thu 31 Mar 02:54:45 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7465400109" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-pets-ok-amazing/7465400109.html" id="postid_7465400109">
#           Pets OK! Amazing Architecture / NY Style Bldg / OPEN HOUSE TODAY!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,325
#          </span>
#          <span class="result-hood">
#           (DTLA / Los Angeles / Westlake District)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7461643217" data-repost-of="7119150224">
#        <a class="result-image gallery" data-ids="3:00w0w_9AKcP2z1JtWz_0ak06T,3:01414_jH3gUYpC6v0z_0ak06T,3:00Y0Y_eDJ449rjCeWz_0ak06T,3:00D0D_avXhZRkUetKz_09G07g,3:00r0r_h7YAuCIAH8Mz_09G07g,3:00e0e_gsPKi0lGUeVz_05r07g,3:00E0E_9gJbyoaYBvaz_09G07g,3:00909_1eKvxtnNCzzz_09G07g,3:00p0p_h55HKjtmNqzz_09G07g,3:00W0W_jHFtsA3CIVuz_09G07g" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-cool-and-hip-ny-style/7461643217.html">
#         <span class="result-price">
#          $1,525
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:54" title="Thu 31 Mar 02:54:07 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7461643217" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-cool-and-hip-ny-style/7461643217.html" id="postid_7461643217">
#           Cool and hip NY Style Apartment / =^.^= Pets OK! Open House TODAY!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,525
#          </span>
#          <span class="result-hood">
#           (Korea Town / Los Angeles / Wilshire Park)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7464415550" data-repost-of="7119150224">
#        <a class="result-image gallery" data-ids="3:00p0p_h55HKjtmNqzz_09G07g,3:00w0w_9AKcP2z1JtWz_0ak06T,3:01414_jH3gUYpC6v0z_0ak06T,3:00Y0Y_eDJ449rjCeWz_0ak06T,3:00D0D_avXhZRkUetKz_09G07g,3:00r0r_h7YAuCIAH8Mz_09G07g,3:00e0e_gsPKi0lGUeVz_05r07g,3:00E0E_9gJbyoaYBvaz_09G07g,3:00606_cLM3qF2sxXQz_09G07g,3:00909_1eKvxtnNCzzz_09G07g,3:00W0W_jHFtsA3CIVuz_09G07g" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-cool-and-hip-ny-style/7464415550.html">
#         <span class="result-price">
#          $1,525
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:53" title="Thu 31 Mar 02:53:57 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7464415550" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-cool-and-hip-ny-style/7464415550.html" id="postid_7464415550">
#           Cool and hip NY Style Apartment / =^.^= Pets OK! Open House TODAY!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,525
#          </span>
#          <span class="result-hood">
#           (Korea Town / Los Angeles / Wilshire Park)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/FHA">
#        fair housing
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/scams">
#         avoiding scams
#        </a>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2022
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl is hiring
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     ‹
#    </div>
#    <div class="slider-forward arrow">
#     ›
#    </div>
#   </template>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lsaquo;</span><span class="slider-info"></span><span class="slider-forward arrow">&rsaquo;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#  </body>
# </html>

# %% [markdown]
# **Option 2.** You can access the same page as I show below, which I saved to the GitHub repository.

# %%
# this is how I saved it
#with open("craigslist_pages/craigslist.txt", "wb") as f:
#    f.write(r.content)

with open("craigslist_pages/craigslist.txt", "r") as f:
    saved_content = f.read()
    
# the saved_content variable now contains what I originally had in r.content
# so we can create a BeautifulSoup object in the same way
soup = BeautifulSoup(saved_content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="central LA housing - craigslist" property="og:title"/>
#   <meta content="central LA housing - craigslist" name="description"/>
#   <meta content="central LA housing - craigslist" property="og:description"/>
#   <meta content="https://losangeles.craigslist.org/search/lac/hhh" property="og:url"/>
#   <meta content="true" name="smartbanner:api"/>
#   <meta content="the craigslist app" name="smartbanner:title"/>
#   <meta content="what's old is new" name="smartbanner:author"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-google"/>
#   <meta content="view" name="smartbanner:button"/>
#   <meta content="close" name="smartbanner:close-label"/>
#   <meta content="https://apps.apple.com/us/app/craigslist/id1336642410" name="smartbanner:button-url-apple"/>
#   <meta content="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile" name="smartbanner:button-url-google"/>
#   <meta content="android,ios" name="smartbanner:enabled-platforms"/>
#   <title>
#    central LA housing - craigslist
#   </title>
#   <link href="https://losangeles.craigslist.org/search/lac/hhh" rel="canonical"/>
#   <link href="https://losangeles.craigslist.org/search/lac/hhh?s=120" rel="next"/>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"losangeles.craigslist.org","@id":"https://losangeles.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"central LA","@id":"https://losangeles.craigslist.org/lac/"},"position":2,"@type":"ListItem"},{"item":{"name":"housing","@id":"https://losangeles.craigslist.org/search/lac/hhh"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <style type="text/css">
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js,
#         #unsupported-browser {
#             position: fixed;
#             z-index: 10000;
#
#             top: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         #no-js p,
#         #unsupported-browser p {
#             color: black;
#             background-color: #FA8787;
#             opacity: 0.8;
#             text-align: center;
#             margin: 0;
#             border: 0;
#             padding: 1em;
#         }
#
#         #unsupported-browser {
#             display: none;
#         }
#
#         .unsupported-browser #unsupported-browser {
#             display: block;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#             font-size: 2em;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#   </style>
#   <script src="https://www.craigslist.org/static/www/4aa05aa5430548804d0c2c9dc3363f638c857c1f.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'browsePostings',
#              {
# areaCountry: "US",
# areaID: "7",
# areaRegion: "CA",
# catAbb: "hhh",
# categoryStr: "hhh",
# countOfTotalText: "image {count} of {total}",
# currencySymbol: "&#x0024;",
# defaultLocale: "en_US",
# defaultView: "grid",
# expiredFavIDs: null,
# hubLinkText: null,
# hubName: null,
# imageConfig: {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}},
# lessInfoText: "less info",
# locParams: null,
# locString: "",
# maptileBaseUrl: "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png",
# maxResults: 3000,
# noImageText: "no image",
# pID: null,
# postalLat: null,
# postalLon: null,
# purveyorCategories: null,
# purveyorStr: "",
# searchDistance: null,
# sectionAbb: "hhh",
# sectionBase: "hhh",
# showInfoText: "show info",
# showMapTabs: 1,
# showingBanished: 0,
# showingFavorites: 0,
# starHint: "save this post in your favorites list",
# subarea: "lac",
# zoomToPosting: null
# },
#              0
#          );
#   </script>
#  </head>
#  <body class="no-js show-curtain opaque search has-map">
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text unrecoverable">
#      There was an error loading the page; please try to
#      <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#       refresh the page.
#      </a>
#     </div>
#     <div class="text message">
#     </div>
#    </div>
#   </div>
#   <noscript id="no-js">
#    <div>
#     <p>
#      We've detected that JavaScript is not enabled in your browser.
#     </p>
#     <p>
#      You must enable JavaScript to use craigslist.
#     </p>
#    </div>
#   </noscript>
#   <div id="unsupported-browser">
#    <p>
#     We've detected you are using a browser that is missing critical features.
#    </p>
#    <p>
#     Please visit craigslist from a modern browser.
#    </p>
#   </div>
#   <section class="page-container" data-areaid="7" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="https://losangeles.craigslist.org/lac/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/lac/hhh" class="breadcrumbs-form" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           los angeles
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="losangeles">
#           los angeles
#          </option>
#          <option value="bakersfield">
#           bakersfield
#          </option>
#          <option value="fresno">
#           fresno
#          </option>
#          <option value="hanford">
#           hanford
#          </option>
#          <option value="imperial">
#           imperial co
#          </option>
#          <option value="inlandempire">
#           inland empire
#          </option>
#          <option value="lasvegas">
#           las vegas
#          </option>
#          <option value="orangecounty">
#           orange co
#          </option>
#          <option value="palmsprings">
#           palm springs
#          </option>
#          <option value="sandiego">
#           san diego
#          </option>
#          <option value="slo">
#           san luis obispo
#          </option>
#          <option value="santabarbara">
#           santa barbara
#          </option>
#          <option value="santamaria">
#           santa maria
#          </option>
#          <option value="ventura">
#           ventura
#          </option>
#          <option value="visalia">
#           visalia-tulare
#          </option>
#          <option value="yuma">
#           yuma
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb subarea">
#         <select id="subArea" name="subArea">
#          <option value="">
#           all los angeles
#          </option>
#          <option value="sfv">
#           SF valley
#          </option>
#          <option value="ant">
#           antelope valley
#          </option>
#          <option selected="" value="lac">
#           central LA
#          </option>
#          <option value="lgb">
#           long beach
#          </option>
#          <option value="sgv">
#           san gabriel valley
#          </option>
#          <option value="wst">
#           westside-southbay
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option selected="" value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="hhh">
#           all
#          </option>
#          <option value="apa">
#           apartments / housing for rent
#          </option>
#          <option value="swp">
#           housing swap
#          </option>
#          <option value="off">
#           office &amp; commercial
#          </option>
#          <option value="prk">
#           parking &amp; storage
#          </option>
#          <option value="reb">
#           real estate - by broker
#          </option>
#          <option value="reo">
#           real estate - by owner
#          </option>
#          <option value="roo">
#           rooms &amp; shares
#          </option>
#          <option value="sub">
#           sublets &amp; temporary
#          </option>
#          <option value="vac">
#           vacation rentals
#          </option>
#          <option value="hou">
#           wanted: apts
#          </option>
#          <option value="rew">
#           wanted: real estate
#          </option>
#          <option value="sha">
#           wanted: room/share
#          </option>
#          <option value="sbw">
#           wanted: sublet/temp
#          </option>
#         </select>
#         <span class="no-js">
#          housing
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/lax">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <div class="to-banish-page">
#         <a class="to-banish-page-link" href="#">
#          <span aria-hidden="true" class="icon icon-trash red">
#          </span>
#          <span class="banished_count">
#           0
#          </span>
#          <span class="discards-label">
#           hidden
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="https://losangeles.craigslist.org/lac/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       central LA            &gt;
#
# housing
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/lac/hhh" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search housing" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Flosangeles%2Ecraigslist%2Eorg%2Fsearch%2Flac%2Fhhh" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="https://losangeles.craigslist.org/search/lac/hhh" title="clear all search parameters">
#        housing
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <ul class="maincats">
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 12 categories
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 12 categories
#          </span>
#          <span class="count">
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="apa" id="cat_apa" name="cat_id" type="checkbox" value="1"/>
#          <a class="category" href="/search/lac/apa">
#           apartments / housing for rent
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="swp" id="cat_swp" name="cat_id" type="checkbox" value="65"/>
#          <a class="category" href="/search/lac/swp">
#           housing swap
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="off" id="cat_off" name="cat_id" type="checkbox" value="40"/>
#          <a class="category" href="/search/lac/off">
#           office &amp; commercial
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="prk" id="cat_prk" name="cat_id" type="checkbox" value="41"/>
#          <a class="category" href="/search/lac/prk">
#           parking &amp; storage
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rea" id="cat_rea" name="cat_id" type="checkbox" value="143,144"/>
#          <a class="category" href="/search/lac/rea">
#           real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="roo" id="cat_roo" name="cat_id" type="checkbox" value="18"/>
#          <a class="category" href="/search/lac/roo">
#           rooms &amp; shares
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sub" id="cat_sub" name="cat_id" type="checkbox" value="39"/>
#          <a class="category" href="/search/lac/sub">
#           sublets &amp; temporary
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vac" id="cat_vac" name="cat_id" type="checkbox" value="99"/>
#          <a class="category" href="/search/lac/vac">
#           vacation rentals
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hou" id="cat_hou" name="cat_id" type="checkbox" value="2"/>
#          <a class="category" href="/search/lac/hou">
#           wanted: apts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rew" id="cat_rew" name="cat_id" type="checkbox" value="121"/>
#          <a class="category" href="/search/lac/rew">
#           wanted: real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sha" id="cat_sha" name="cat_id" type="checkbox" value="19"/>
#          <a class="category" href="/search/lac/sha">
#           wanted: room/share
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sbw" id="cat_sbw" name="cat_id" type="checkbox" value="58"/>
#          <a class="category" href="/search/lac/sbw">
#           wanted: sublet/temp
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <div class="selectall js-only checked">
#           <label>
#            <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#            <span class="all linklike">
#             select all
#            </span>
#           </label>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div class="searchgroup" id="basic-bools">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from location
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value="">
#          <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#          <span class="icon icon-locate">
#          </span>
#         </input>
#        </div>
#        <div class="searchgroup minmax price" id="price">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bedrooms
#         </span>
#         <select class="autosubmit" name="min_bedrooms">
#          <option value="">
#           min
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bedrooms">
#          <option value="">
#           max
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bathrooms
#         </span>
#         <select class="autosubmit" name="min_bathrooms">
#          <option value="">
#           min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bathrooms">
#          <option value="">
#           max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax" id="">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          availability
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option value="0">
#           all dates
#          </option>
#          <option value="1">
#           within 30 days
#          </option>
#          <option value="2">
#           beyond 30 days
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup search-group-checkbox">
#         <label class="private_room">
#          <input class="autosubmit" name="private_room" type="checkbox" value="1">
#           private room
#          </input>
#         </label>
#         <br/>
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#           cats ok
#          </input>
#         </label>
#         <br/>
#         <label class="private_bath">
#          <input class="autosubmit" name="private_bath" type="checkbox" value="1">
#           private bath
#          </input>
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#           dogs ok
#          </input>
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1">
#           furnished
#          </input>
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#           no smoking
#          </input>
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#           wheelchair access
#          </input>
#         </label>
#         <br/>
#         <label class="airconditioning">
#          <input class="autosubmit" name="airconditioning" type="checkbox" value="1">
#           air conditioning
#          </input>
#         </label>
#         <br/>
#         <label class="ev_charging">
#          <input class="autosubmit" name="ev_charging" type="checkbox" value="1">
#           EV charging
#          </input>
#         </label>
#         <br/>
#         <label class="application_fee">
#          <input class="autosubmit" name="application_fee" type="checkbox" value="1">
#           no application fee
#          </input>
#         </label>
#         <br/>
#         <label class="broker_fee">
#          <input class="autosubmit" name="broker_fee" type="checkbox" value="1">
#           no broker fee
#          </input>
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup search-group-multi_checkbox">
#         <div class="search-attribute hide-list" data-attr="housing_type">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           housing type
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_1" name="housing_type" type="checkbox" value="1">
#              apartment
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_2" name="housing_type" type="checkbox" value="2">
#              condo
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_3" name="housing_type" type="checkbox" value="3">
#              cottage/cabin
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_4" name="housing_type" type="checkbox" value="4">
#              duplex
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_5" name="housing_type" type="checkbox" value="5">
#              flat
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_6" name="housing_type" type="checkbox" value="6">
#              house
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_7" name="housing_type" type="checkbox" value="7">
#              in-law
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_8" name="housing_type" type="checkbox" value="8">
#              loft
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_9" name="housing_type" type="checkbox" value="9">
#              townhouse
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_10" name="housing_type" type="checkbox" value="10">
#              manufactured
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_11" name="housing_type" type="checkbox" value="11">
#              assisted living
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_12" name="housing_type" type="checkbox" value="12"/>
#             land
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           laundry
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1"/>
#             w/d in unit
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4"/>
#             w/d hookups
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2"/>
#             laundry in bldg
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             laundry on site
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             no laundry on site
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           parking
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             carport
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             attached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             detached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             off-street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             valet parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             no parking
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="rent_period">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           rent period
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_1" name="rent_period" type="checkbox" value="1"/>
#             daily
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_2" name="rent_period" type="checkbox" value="2"/>
#             weekly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_3" name="rent_period" type="checkbox" value="3"/>
#             monthly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_4" name="rent_period" type="checkbox" value="4"/>
#             yearly
#            </label>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <div class="searchfieldlabel">
#          open house date
#         </div>
#         <select class="autosubmit" id="sale_date" name="sale_date">
#          <option>
#           all dates
#          </option>
#          <option value="2022-03-31">
#           mar 31 - today
#          </option>
#          <option value="2022-04-01">
#           apr 1 - tomorrow
#          </option>
#          <option value="2022-04-02">
#           apr 2 - saturday
#          </option>
#          <option value="2022-04-03">
#           apr 3 - sunday
#          </option>
#          <option value="2022-04-04">
#           apr 4 - monday
#          </option>
#          <option value="2022-04-05">
#           apr 5 - tuesday
#          </option>
#          <option value="2022-04-06">
#           apr 6 - wednesday
#          </option>
#          <option value="2022-04-07">
#           apr 7 - thursday
#          </option>
#          <option value="2022-04-08">
#           apr 8 - friday
#          </option>
#          <option value="2022-04-09">
#           apr 9 - saturday
#          </option>
#          <option value="2022-04-10">
#           apr 10 - sunday
#          </option>
#          <option value="2022-04-11">
#           apr 11 - monday
#          </option>
#          <option value="2022-04-12">
#           apr 12 - tuesday
#          </option>
#          <option value="2022-04-13">
#           apr 13 - wednesday
#          </option>
#          <option value="2022-04-14">
#           apr 14 - thursday
#          </option>
#          <option value="2022-04-15">
#           apr 15 - friday
#          </option>
#          <option value="2022-04-16">
#           apr 16 - saturday
#          </option>
#          <option value="2022-04-17">
#           apr 17 - sunday
#          </option>
#          <option value="2022-04-18">
#           apr 18 - monday
#          </option>
#          <option value="2022-04-19">
#           apr 19 - tuesday
#          </option>
#          <option value="2022-04-20">
#           apr 20 - wednesday
#          </option>
#          <option value="2022-04-21">
#           apr 21 - thursday
#          </option>
#          <option value="2022-04-22">
#           apr 22 - friday
#          </option>
#          <option value="2022-04-23">
#           apr 23 - saturday
#          </option>
#          <option value="2022-04-24">
#           apr 24 - sunday
#          </option>
#          <option value="2022-04-25">
#           apr 25 - monday
#          </option>
#          <option value="2022-04-26">
#           apr 26 - tuesday
#          </option>
#          <option value="2022-04-27">
#           apr 27 - wednesday
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="https://losangeles.craigslist.org/search/lac/hhh" title="clear all search parameters">
#          reset
#         </a>
#         <button class="searchlink linklike" type="submit">
#          update search
#         </button>
#        </div>
#        <aside class="tsb">
#         <ul>
#          <li>
#           <a href="https://www.craigslist.org/about/FHA">
#            fair housing
#           </a>
#           <li>
#            <a href="https://www.craigslist.org/about/scams">
#             avoiding scams
#            </a>
#           </li>
#          </li>
#         </ul>
#        </aside>
#       </input>
#      </div>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="show results in a list">
#           <span class="view-list icon">
#           </span>
#           list
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
#           <span class="view-thumb icon">
#           </span>
#           thumb
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
#           <span class="view-gallery icon">
#           </span>
#           gallery
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="map" id="mapview" title="show results on a map">
#           <span class="view-map icon">
#           </span>
#           map
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="upcoming" href="/search/lac/hhh?sort=upcoming&amp;" title="show upcoming open houses">
#           upcoming
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="true" class="dropdown-item mode sel">
#          <a data-selection="date" href="/search/lac/hhh?sort=date&amp;" title="show newest matches first">
#           newest
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="priceasc" href="/search/lac/hhh?sort=priceasc&amp;" title="sort by price, lowest to highest">
#           price ↑
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="pricedsc" href="/search/lac/hhh?sort=pricedsc&amp;" title="sort by price, highest to lowest">
#           price ↓
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <div class="content" id="sortable-results">
#      <section class="favlistsection">
#       <section class="favlistinfo">
#       </section>
#       <section class="banishlistinfo">
#       </section>
#      </section>
#      <div class="open-map-view-button">
#       <span>
#        see in map view
#       </span>
#      </div>
#      <div data-arealat="34.052200" data-arealon="-118.242996" id="mapcontainer">
#       <div id="update-search-area-button">
#       </div>
#       <div id="noresult-overlay">
#       </div>
#       <div id="noresult-text">
#        <span class="message">
#         No mappable items found
#        </span>
#       </div>
#       <div class="loading" id="map">
#        <div class="close-full-screen-map-mode-button">
#         close fullscreen
#        </div>
#       </div>
#      </div>
#      <ul class="rows" id="search-results">
#       <li class="result-row" data-pid="7462867093">
#        <a class="result-image gallery" data-ids="3:00x0x_hYj1h9Urou4z_05a03r,3:00m0m_lxq8kHsnewGz_05a03r,3:00q0q_lJfN76ZHs6Dz_0c60c6,3:00J0J_kDO26Oo9zJVz_05a03r,3:01414_9YJJ8lWgSDGz_05a03r,3:00z0z_6144zJkcPUSz_05a03r,3:00303_2kauOPexgjiz_05a03r,3:00u0u_1pXEjvo1UeHz_05a03r" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html">
#         <span class="result-price">
#          $2,363
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:12" title="Thu 31 Mar 02:12:22 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7462867093" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html" id="postid_7462867093">
#           Dishwasher, Outdoor Fireplace, Built-in Microwave
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $2,363
#          </span>
#          <span class="housing">
#           1br -
#                     647ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (550 N. Figueroa st., Los Angeles, CA)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7452624334">
#        <a class="result-image gallery" data-ids="3:00K0K_jfIzcF0YQLlz_0ew092,3:00f0f_ihREhduKwCtz_0ew092,3:00o0o_9eWAMX8eXyAz_0ew092,3:00606_21M5wHppJMiz_0ew092,3:00707_1197Ogw9l59z_0ew092,3:00707_bMJceHKCij1z_0ew092,3:00Q0Q_fEKw88izRcDz_0ew092,3:00P0P_6SCjE1n2AGFz_0jm0g8" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-public-transportation-high/7452624334.html">
#         <span class="result-price">
#          $4,380
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 14:12" title="Thu 31 Mar 02:12:15 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7452624334" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-public-transportation-high/7452624334.html" id="postid_7452624334">
#           Public Transportation, High-speed Internet, Green Apartment
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $4,380
#          </span>
# ...
#         <span class="result-price">
#          $1,575
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 13:01" title="Thu 31 Mar 01:01:17 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7460256277" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-wood-style-floors/7460256277.html" id="postid_7460256277">
#           Wood Style Floors | Refrigerator | 2 Weeks Free | Studio in Koreatown
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,575
#          </span>
#          <span class="result-hood">
#           (Hollywood)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7464494963">
#        <a class="result-image gallery" data-ids="3:00000_4THt0mUM7Udz_0b10gw,3:00505_foEjNuFJ0VDz_0jm0aT,3:00707_aKzQdjaCcUkz_0gw0b1,3:01010_9dhJiNYxzcVz_0gw0b1,3:01313_bLQB3tkEBBCz_0gw0b1,3:00i0i_glDELxPH507z_0gw0b1,3:00B0B_1q1eQBDc8gz_0gw0b1,3:00f0f_kQkx5AmajLRz_0hK0c6,3:01010_cTqJZDggGM4z_0oc0oj" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-available-now-2895-vaulted/7464494963.html">
#         <span class="result-price">
#          $2,995
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 13:01" title="Thu 31 Mar 01:01:09 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7464494963" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-available-now-2895-vaulted/7464494963.html" id="postid_7464494963">
#           Available Now-$2895, Vaulted Ceilings, Stainless Apps, A/C
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $2,995
#          </span>
#          <span class="housing">
#           2br -
#                     1038ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (5015 Clinton Street, Los Angeles, CA)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7464450814">
#        <a class="result-image gallery" data-ids="3:00H0H_9cIkL3sOWOyz_08I06i,3:00e0e_iR4kF3qUre8z_08I06i,3:00404_8aeOOSOa2Y5z_08I06i,3:00H0H_71gzpxzT07fz_08I06i,3:00l0l_gteqlZSteoVz_08I06i,3:00t0t_eMVbSOLAyJaz_08I06i,3:00c0c_iRBmWk0tD83z_08I06i,3:00404_evQ0zRJTJjxz_08I06i,3:00C0C_d88dIbjHPVzz_09i06Y" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-above-standard-ceiling/7464450814.html">
#         <span class="result-price">
#          $3,595
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 13:00" title="Thu 31 Mar 01:00:28 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7464450814" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-above-standard-ceiling/7464450814.html" id="postid_7464450814">
#           Above Standard Ceiling Height, GymPhoto, Fire Pit AreaPhoto
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $3,595
#          </span>
#          <span class="housing">
#           2br -
#                     1265ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (central LA 213/323)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7465348249" data-repost-of="7357986954">
#        <a class="result-image gallery" data-ids="3:00m0m_93kKDgFRcdOz_0CI0pO,3:00X0X_2pR60zbbpS3z_0jR0de,3:00d0d_1PiljgkrBziz_0pl0gT,3:00X0X_93yEZn0Cw7Cz_0j40cI,3:00S0S_17cRrXspIH7z_0md0eO,3:00707_gXOS7eunmE5z_0kU0dW,3:00505_dR4vWzEHD3Xz_0p50gI,3:00b0b_fv6T5jOiViYz_0ii0cc,3:00G0G_9N5dSw4dlYYz_0oP0gy,3:00C0C_5lHIRcKTNo2z_0nw0fG,3:00A0A_bwP3etCMJhoz_0kU0dW,3:01515_l0fmdGZAxyzz_0iy0cm,3:00F0F_2YRI4cIlx5Az_0oy0gn,3:00N0N_5HwZPprJJh7z_0oy0gn" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bedroom-ba-in-koreatown/7465348249.html">
#         <span class="result-price">
#          $2,350
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-03-31 13:00" title="Thu 31 Mar 01:00:11 PM">
#          Mar 31
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7465348249" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bedroom-ba-in-koreatown/7465348249.html" id="postid_7465348249">
#           2 Bedroom 2 BA in Koreatown - Cozy Fireplace - Central A/C - Renovated
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $2,350
#          </span>
#          <span class="housing">
#           2br -
#                     740ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Los Angeles / Koreatown)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/FHA">
#        fair housing
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/scams">
#         avoiding scams
#        </a>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2022
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl is hiring
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     ‹
#    </div>
#    <div class="slider-forward arrow">
#     ›
#    </div>
#   </template>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lsaquo;</span><span class="slider-info"></span><span class="slider-forward arrow">&rsaquo;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#  </body>
# </html>

# %% [markdown]
# Let's look at the output to figure out how to parse it.
#
# Again, this takes some detective work and trial and error.
#
# It looks like each post is in a `<li>` tag. Moreover, note that it's also in a `class` called `result-row`. Structured data like this make it much easier to scrape! The `find_all()` function takes an optional `class_` argument that can filter by class.

# %%
posts = soup.find_all('li', class_= 'result-row')

# Note that there are 120 results, which is the number of posts returned on the Craigslist webpage. 
# That's a good sign!
print(len(posts))
# Out:
# 120

# %% [markdown]
# Let's look at a sample post.

# %%
posts[0]
# Out:
# <li class="result-row" data-pid="7462867093">
# <a class="result-image gallery" data-ids="3:00x0x_hYj1h9Urou4z_05a03r,3:00m0m_lxq8kHsnewGz_05a03r,3:00q0q_lJfN76ZHs6Dz_0c60c6,3:00J0J_kDO26Oo9zJVz_05a03r,3:01414_9YJJ8lWgSDGz_05a03r,3:00z0z_6144zJkcPUSz_05a03r,3:00303_2kauOPexgjiz_05a03r,3:00u0u_1pXEjvo1UeHz_05a03r" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html">
# <span class="result-price">$2,363</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2022-03-31 14:12" title="Thu 31 Mar 02:12:22 PM">Mar 31</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7462867093" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html" id="postid_7462867093">Dishwasher, Outdoor Fireplace, Built-in Microwave</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$2,363</span>
# <span class="housing">
#                     1br -
#                     647ft<sup>2</sup> -
#                 </span>
# <span class="result-hood"> (550 N. Figueroa st., Los Angeles, CA)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %% [markdown]
# It looks like the price and the neighborhood have their own class, within the `span` tag.
# The title and URL look like they are within the `a` tag. The number of bedrooms is a bit more complicated, but it's somewhere in the housing class.
#
# Let's test this out. Note that `find()` will get the first occurence.

# %%
print(posts[0].find('span', class_= 'result-price').text)
# Out:
# $2,363

# %% [markdown]
# `find_all()` will get all of them, and return a list. But in the craigslist posts, there's only either one occurence or they are all the same, so `find` is easier.

# %%
print(posts[0].find_all('span', class_= 'result-price'))
# Out:
# [<span class="result-price">$2,363</span>, <span class="result-price">$2,363</span>]

# %% [markdown]
# Notice that we got a 1-element list. We'd then have to get the first element, and use `text` to get the text that is contained.

# %%
print(posts[0].find_all('span', class_= 'result-price')[0].text)
# Out:
# $2,363

# %% [markdown]
# What about the other attributes that might be interesting?

# %%
print('\nNeighborhood:') # \n adds an empty line before
print(posts[0].find('span', class_= 'result-hood').text)

print('\nHousing size:')
print(posts[0].find('span', class_= 'housing').text)

print('\nTitle:')
print(posts[0].find('a', class_= 'result-title').text)
# Out:
# Neighborhood:
#  (550 N. Figueroa st., Los Angeles, CA)
#
# Housing size:
#
#                     1br -
#                     647ft2 -
#
#
# Title:
# Dishwasher, Outdoor Fireplace, Built-in Microwave

# %% [markdown]
# We can also extract the URL of the page that is linked. But if you look at the output above, it's not in the text, but within the `result-title` class.

# %%
# except the URL has it's own key
print('\nURL:')
print(posts[0].find('a', class_= 'result-title'))
# Out:
# URL:
# <a class="result-title hdrlnk" data-id="7462867093" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html" id="postid_7462867093">Dishwasher, Outdoor Fireplace, Built-in Microwave</a>

# %% [markdown]
# So we can extract it by calling the `href` key.

# %%
print(posts[0].find('a', class_= 'result-title')['href'])
# Out:
# https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html

# %% [markdown]
# Now we understand the structure of each page. So we are ready to put all of the posts in a dataframe.
#
# `pandas` can create a dataframe from many different data structures. But one of the easiest ways to is to create a list of dictionaries, and then tell `pandas` to convert that into a dataframe.
#
# Each element of the list will be a craigslist post. Within that list element, we have a dictionary of columns.

# %% [markdown]
# Remember that `posts` held our list of posts

# %%
print(type(posts))
print(len(posts))
# Out:
# <class 'bs4.element.ResultSet'>
# 120

# %%
print(posts[0])
# Out:
# <li class="result-row" data-pid="7462867093">
# <a class="result-image gallery" data-ids="3:00x0x_hYj1h9Urou4z_05a03r,3:00m0m_lxq8kHsnewGz_05a03r,3:00q0q_lJfN76ZHs6Dz_0c60c6,3:00J0J_kDO26Oo9zJVz_05a03r,3:01414_9YJJ8lWgSDGz_05a03r,3:00z0z_6144zJkcPUSz_05a03r,3:00303_2kauOPexgjiz_05a03r,3:00u0u_1pXEjvo1UeHz_05a03r" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html">
# <span class="result-price">$2,363</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2022-03-31 14:12" title="Thu 31 Mar 02:12:22 PM">Mar 31</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7462867093" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-dishwasher-outdoor/7462867093.html" id="postid_7462867093">Dishwasher, Outdoor Fireplace, Built-in Microwave</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$2,363</span>
# <span class="housing">
#                     1br -
#                     647ft<sup>2</sup> -
#                 </span>
# <span class="result-hood"> (550 N. Figueroa st., Los Angeles, CA)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %% [markdown]
# So let's loop over them.

# %%
import pandas as pd
postList = [] # empty list that we can append to

for post in posts:
    # create temporary variables with the attributes that we extract from each post
    price = post.find('span', class_= 'result-price').text
    neighborhood = post.find('span', class_= 'result-hood').text
    housingsize = post.find('span', class_= 'housing').text
    title = post.find('a', class_= 'result-title').text
    url = post.find('a', class_= 'result-title')['href']

    # put them all in a dictionary
    postDict = {'price': price, 'neighborhood':neighborhood, 
                'housingsize':housingsize, 'title':title, 'url':url}
    
    # append that dictionary to our list
    postList.append(postDict)
    
# turn the list into a dataframe
df = pd.DataFrame(postList)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [103], in <cell line: 4>()
#       6 price = post.find('span', class_= 'result-price').text
#       7 neighborhood = post.find('span', class_= 'result-hood').text
# ----> 8 housingsize = post.find('span', class_= 'housing').text
#       9 title = post.find('a', class_= 'result-title').text
#      10 url = post.find('a', class_= 'result-title')['href']
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ### Catching exceptions
# What went wrong? Let's unpack this error.
#
# It looks like we couldn't get our `housingsize` variable, because there was no text.
#
# So what if we back up and see what that object looks like, before we try and get the text?

# %%
post.find('span', class_= 'housing')

# %% [markdown]
# Nothing! How come?

# %%
print(type(post.find('span', class_= 'housing')))
# Out:
# <class 'NoneType'>

# %% [markdown]
# Aha. It's a `None` object - basically empty. And so we can't ask to get the text where nothing exists.
#
# How can we be more robust to these errors (technically, "exceptions")?
#
# One way is to use `try...except`. We `try` a block of code, and if something goes wrong, we execute the alternative code under `except`.

# %%
import pandas as pd
postList = [] # empty list that we can append to

for post in posts:
    try:
        # create temporary variables with the attributes that we extract from each post
        price = post.find('span', class_= 'result-price').text
        neighborhood = post.find('span', class_= 'result-hood').text
        housingsize = post.find('span', class_= 'housing').text
        title = post.find('a', class_= 'result-title').text
        url = post.find('a', class_= 'result-title')['href']

        # put them all in a dictionary
        postDict = {'price': price, 'neighborhood':neighborhood, 
                    'housingsize':housingsize, 'title':title, 'url':url}

        # append that dictionary to our list
        postList.append(postDict)
    except: # we could also be more specific, e.g. except AttributeError:
        # this is only excecuted if the code under try fails
        # if there's a problem, we'll just append an empty dictionary
        postList.append({})
    
# turn the list into a dataframe
df = pd.DataFrame(postList)

df
# Out:
#       price                             neighborhood  \
# 0    $2,363   (550 N. Figueroa st., Los Angeles, CA)
# 1    $4,380                     (central LA 213/323)
# 2      $950                              (Echo Park)
# 3    $1,800                            (Los Angeles)
# 4    $1,694      (101 Bridewell St, Los Angeles, CA)
# ..      ...                                      ...
# 115  $1,905                  (Koreatown/Downtown LA)
# 116     NaN                                      NaN
# 117  $2,995   (5015 Clinton Street, Los Angeles, CA)
# 118  $3,595                     (central LA 213/323)
# 119  $2,350                (Los Angeles / Koreatown)
#
#                                            housingsize  \
# 0    \n                    1br -\n                 ...
# 1    \n                    2br -\n                 ...
# 2    \n                    1br -\n                 ...
# 3    \n                    1br -\n                 ...
# 4     \n                    440ft2 -\n
# ..                                                 ...
# 115   \n                    435ft2 -\n
# 116                                                NaN
# 117  \n                    2br -\n                 ...
# 118  \n                    2br -\n                 ...
# 119  \n                    2br -\n                 ...
#
#                                                  title  \
# 0    Dishwasher, Outdoor Fireplace, Built-in Microwave
# 1    Public Transportation, High-speed Internet, Gr...
# 2    FOR RENT-LARGE, BRIGHT, FURNISHED 11x14 PRIVAT...
# 3    Gorgeous move-in ready unit located in a heart...
# 4      Separate Dining Areas, Plush Carpeting, Sundeck
# ..                                                 ...
# 115  Vinyl Plank Flooring | SS Appliances | Brand N...
# 116                                                NaN
# 117  Available Now-$2895, Vaulted Ceilings, Stainle...
# 118  Above Standard Ceiling Height, GymPhoto, Fire ...
# 119  2 Bedroom 2 BA in Koreatown - Cozy Fireplace -...
#
#                                                    url
# 0    https://losangeles.craigslist.org/lac/apa/d/lo...
# 1    https://losangeles.craigslist.org/lac/apa/d/lo...
# 2    https://losangeles.craigslist.org/lac/roo/d/lo...
# 3    https://losangeles.craigslist.org/lac/apa/d/lo...
# 4    https://losangeles.craigslist.org/lac/apa/d/lo...
# ..                                                 ...
# 115  https://losangeles.craigslist.org/lac/apa/d/lo...
# 116                                                NaN
# 117  https://losangeles.craigslist.org/lac/apa/d/lo...
# 118  https://losangeles.craigslist.org/lac/apa/d/lo...
# 119  https://losangeles.craigslist.org/lac/apa/d/lo...
#
# [120 rows x 5 columns]

# %% [markdown]
# So we find the errant row - 116. (There could be others too.)
#
# The `try...except` syntax is useful, but a blunt instrument. Notice that we lose all the data for that posting, not just the housing size.
#
# As an alternative, we could explicitly check for missing data at each step.

# %%
postList = []

for post in posts:
    result_price = post.find('span', class_= 'result-price')
    if result_price is None:
        price = None
    else:
        price = result_price.text
    
    resulthood = post.find('span', class_= 'result-hood')
    if resulthood is None:
        neighborhood = None
    else:
        neighborhood = resulthood.text 
        
    # we can also have our if..else statements as a one-liner
    # this is identical to the above
    neighborhood = None if resulthood is None else resulthood.text

    housing = post.find('span', class_= 'housing')
    housingsize = None if housing is None else housing.text
        
    # these two fields seem to be always present, so no need to check for None
    title = post.find('a', class_= 'result-title').text
    url = post.find('a', class_= 'result-title')['href']

    # now put them in the dictionary, and append to our list
    postList.append({'price': price, 'neighborhood':neighborhood, 
                     'housingsize':housingsize, 'title':title, 'url':url})

df = pd.DataFrame(postList)

df
# Out:
#       price                             neighborhood  \
# 0    $2,363   (550 N. Figueroa st., Los Angeles, CA)
# 1    $4,380                     (central LA 213/323)
# 2      $950                              (Echo Park)
# 3    $1,800                            (Los Angeles)
# 4    $1,694      (101 Bridewell St, Los Angeles, CA)
# ..      ...                                      ...
# 115  $1,905                  (Koreatown/Downtown LA)
# 116  $1,575                              (Hollywood)
# 117  $2,995   (5015 Clinton Street, Los Angeles, CA)
# 118  $3,595                     (central LA 213/323)
# 119  $2,350                (Los Angeles / Koreatown)
#
#                                            housingsize  \
# 0    \n                    1br -\n                 ...
# 1    \n                    2br -\n                 ...
# 2    \n                    1br -\n                 ...
# 3    \n                    1br -\n                 ...
# 4     \n                    440ft2 -\n
# ..                                                 ...
# 115   \n                    435ft2 -\n
# 116                                               None
# 117  \n                    2br -\n                 ...
# 118  \n                    2br -\n                 ...
# 119  \n                    2br -\n                 ...
#
#                                                  title  \
# 0    Dishwasher, Outdoor Fireplace, Built-in Microwave
# 1    Public Transportation, High-speed Internet, Gr...
# 2    FOR RENT-LARGE, BRIGHT, FURNISHED 11x14 PRIVAT...
# 3    Gorgeous move-in ready unit located in a heart...
# 4      Separate Dining Areas, Plush Carpeting, Sundeck
# ..                                                 ...
# 115  Vinyl Plank Flooring | SS Appliances | Brand N...
# 116  Wood Style Floors | Refrigerator | 2 Weeks Fre...
# 117  Available Now-$2895, Vaulted Ceilings, Stainle...
# 118  Above Standard Ceiling Height, GymPhoto, Fire ...
# 119  2 Bedroom 2 BA in Koreatown - Cozy Fireplace -...
#
#                                                    url
# 0    https://losangeles.craigslist.org/lac/apa/d/lo...
# 1    https://losangeles.craigslist.org/lac/apa/d/lo...
# 2    https://losangeles.craigslist.org/lac/roo/d/lo...
# 3    https://losangeles.craigslist.org/lac/apa/d/lo...
# 4    https://losangeles.craigslist.org/lac/apa/d/lo...
# ..                                                 ...
# 115  https://losangeles.craigslist.org/lac/apa/d/lo...
# 116  https://losangeles.craigslist.org/lac/apa/d/lo...
# 117  https://losangeles.craigslist.org/lac/apa/d/lo...
# 118  https://losangeles.craigslist.org/lac/apa/d/lo...
# 119  https://losangeles.craigslist.org/lac/apa/d/lo...
#
# [120 rows x 5 columns]

# %% [markdown]
# Notice that we got some partial data for row 116.

# %% [markdown]
# ### Parsing and cleaning the text

# %% [markdown]
# So it looks pretty good, except for the `housingsize` field. What's going on here?

# %%
df.housingsize
# Out:
# 0      \n                    1br -\n                 ...
# 1      \n                    2br -\n                 ...
# 2      \n                    1br -\n                 ...
# 3      \n                    1br -\n                 ...
# 4       \n                    440ft2 -\n
#                              ...
# 115     \n                    435ft2 -\n
# 116                                                 None
# 117    \n                    2br -\n                 ...
# 118    \n                    2br -\n                 ...
# 119    \n                    2br -\n                 ...
# Name: housingsize, Length: 120, dtype: object

# %% [markdown]
# Hmm. Not very helpful. Let's look at the first row.

# %%
print(df.housingsize.iloc[0])
# Out:
#                     1br -
#                     647ft2 -

# %% [markdown]
# It looks like there is a lot of whitespace here. And sometimes, the field contains ft2, sometimes br, sometimes neither and sometimes both.
#
# This
#
# Let's use the `str.split()` function to split the string by the whitespace. The function takes a string, and returns a list.

# %%
str.split?

# %%
# example
'Splitting this sentence into words'.split()
# Out:
# ['Splitting', 'this', 'sentence', 'into', 'words']

# %% [markdown]
# We can apply the `split()` function to every row of the pandas dataframe.

# %%
print(df.housingsize.str.split())
# Out:
# 0       [1br, -, 647ft2, -]
# 1      [2br, -, 1078ft2, -]
# 2       [1br, -, 154ft2, -]
# 3       [1br, -, 873ft2, -]
# 4               [440ft2, -]
#                ...
# 115             [435ft2, -]
# 116                    None
# 117    [2br, -, 1038ft2, -]
# 118    [2br, -, 1265ft2, -]
# 119     [2br, -, 740ft2, -]
# Name: housingsize, Length: 120, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Conceptually, how would you go about creating two new fields in the dataframe—bedrooms and sqft? Write some code if you can, but the most important step is to think through how you'd do it in words.
# </div>

# %% [markdown]
# We need to consider the possibilities that the list has information on bedrooms, square feet, both or neither. So let's write a function that looks at each element of the list.

# %%
import numpy as np
def extract_sqft(housingsize):
    if housingsize is None:
        return np.nan
    
    hlist = housingsize.split()
    sqft = None  # set the variable as None at the start, in case the loop below doesn't return a match
    
    # loop over each element of the list and check to see if ft2 is there
    for h in hlist:
        if 'ft2' in h:
            # if it is, clean up the string. We replace 'ft2' with an empty string, and convert to an integer
            sqft = int(h.replace('ft2',''))
    return sqft

# try it with one example
# the triple quotes allow a string to extend over multiple lines
extract_sqft('''1br -
                    647ft2 -''')
# Out:
# 647

# %%
# apply it to all rows
df['sq_ft']=df.housingsize.apply(extract_sqft)
df.head()
# Out:
#     price                             neighborhood  \
# 0  $2,363   (550 N. Figueroa st., Los Angeles, CA)
# 1  $4,380                     (central LA 213/323)
# 2    $950                              (Echo Park)
# 3  $1,800                            (Los Angeles)
# 4  $1,694      (101 Bridewell St, Los Angeles, CA)
#
#                                          housingsize  \
# 0  \n                    1br -\n                 ...
# 1  \n                    2br -\n                 ...
# 2  \n                    1br -\n                 ...
# 3  \n                    1br -\n                 ...
# 4   \n                    440ft2 -\n
#
#                                                title  \
# 0  Dishwasher, Outdoor Fireplace, Built-in Microwave
# 1  Public Transportation, High-speed Internet, Gr...
# 2  FOR RENT-LARGE, BRIGHT, FURNISHED 11x14 PRIVAT...
# 3  Gorgeous move-in ready unit located in a heart...
# 4    Separate Dining Areas, Plush Carpeting, Sundeck
#
#                                                  url   sq_ft
# 0  https://losangeles.craigslist.org/lac/apa/d/lo...   647.0
# 1  https://losangeles.craigslist.org/lac/apa/d/lo...  1078.0
# 2  https://losangeles.craigslist.org/lac/roo/d/lo...   154.0
# 3  https://losangeles.craigslist.org/lac/apa/d/lo...   873.0
# 4  https://losangeles.craigslist.org/lac/apa/d/lo...   440.0

# %% [markdown]
# You could write a similar function to extract the number of bedrooms.
#
# ### Plotting
#
# Now let's plot the distribution of price. A box plot would be a good choice here.

# %%
df.boxplot('price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 df.boxplot('price')
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/plotting/_core.py:511, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     494 @Substitution(backend=_backend_doc)
#     495 @Appender(_boxplot_doc)
#     496 def boxplot_frame(
#    (...)
#     508     **kwargs,
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#     514         by=by,
#     515         ax=ax,
#     516         fontsize=fontsize,
#     517         rot=rot,
#     518         grid=grid,
#     519         figsize=figsize,
#     520         layout=layout,
#     521         return_type=return_type,
#     522         **kwargs,
#     523     )
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:425, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     410 def boxplot_frame(
#     411     self,
#     412     column=None,
#    (...)
#     421     **kwds,
#     422 ):
#     423     import matplotlib.pyplot as plt
# --> 425     ax = boxplot(
#     426         self,
#     427         column=column,
#     428         by=by,
#     429         ax=ax,
#     430         fontsize=fontsize,
#     431         grid=grid,
#     432         rot=rot,
#     433         figsize=figsize,
#     434         layout=layout,
#     435         return_type=return_type,
#     436         **kwds,
#     437     )
#     438     plt.draw_if_interactive()
#     439     return ax
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:402, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     400     columns = data.columns
#     401 else:
# --> 402     data = data[columns]
#     404 result = plot_group(columns, data.values.T, ax)
#     405 ax.grid(grid)
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['price'], dtype='object')] are in the [columns]"

# %% [markdown]
# Oops. What went wrong?
#
# The error message isn't terribly helpful, so let's look at the data.

# %%
df.price.head()
# Out:
# 0    $2,363
# 1    $4,380
# 2      $950
# 3    $1,800
# 4    $1,694
# Name: price, dtype: object

# %% [markdown]
# Aha. We can't do a boxplot of a string! So let's convert it to a number. This is a three-stage process:
# * Remove the `$` (replace `$` with an empty string)
# * Do the same for the `,`
# * Convert to a float. The pandas `astype` function is useful here.
#
# Let's do this and store the output in a new column, `price_numeric`.

# %%
df['price_numeric'] = df.price.str.replace('$','').str.replace(',','').astype(float)
# Out:
# /var/folders/b7/h5f5948x0295kq2k3khb96kc0000gn/T/ipykernel_2306/2425117574.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price_numeric'] = df.price.str.replace('$','').str.replace(',','').astype(float)

# %%
df.boxplot('price_numeric')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can also break it out by neighborhood using the `by` argument.
#
# But what's the problem here?

# %%
df.boxplot('price_numeric', by='neighborhood')
# Out:
# <AxesSubplot:title={'center':'price_numeric'}, xlabel='neighborhood'>

# %% [markdown]
# There are several ways to examine the contents of a pandas DataFrame column. `unique()` can be useful.
#
# Here, we see that there isn't a fixed set of neighborhood names, and so further cleaning would be needed.

# %%
df.neighborhood.unique()
# Out:
# array([' (550 N. Figueroa st., Los Angeles, CA)', ' (central LA 213/323)',
#        ' (Echo Park)', ' (Los Angeles)',
#        ' (101 Bridewell St, Los Angeles, CA)',
#        ' (Hollywood - West Hollywood Adj)', ' (Hollywood)',
#        ' (1810 S FAIRFAX Avenue Los Angeles, CA)',
#        ' (3205 Los Feliz Boulevard, Los Angeles, CA)',
#        ' (1026 S Broadway, Los Angeles, CA)', ' (Silver Lake)',
#        ' (1221 W. 3rd St. , Los Angeles, CA)', ' (west hollywood)',
#        ' (Stevenson Ranch)', ' (909 W. Temple St., Los Angeles, CA)',
#        ' (Colorado)', ' (Pacoima, CA)', ' (NORMANDIE & 38TH)',
#        ' (LOS ANGELES)', ' (central LA)',
#        ' (Washington state bonney lake)', ' (South Park dtla)',
#        ' (531 North Hobart Boulevard, Los Angeles, CA)',
#        ' (EAST LOS ANGELES)', ' (Franklin Village)',
#        ' (Glendale/Burbank [[OR WITHIN CLOSE PROXIMITY]])',
#        ' (Los Angeles, CA)',
#        ' (4555 W. Martin Luther King Jr. Blvd Los Angeles, CA)',
#        ' (Los Angeles, CA.)',
#        ' (5351 San Vicente Boulevard, Los Angeles, CA)', ' (Koreatown)',
#        ' (West Hollywood)', ' (Los Angeles / Miracle Mile)',
#        ' (HOLLYWOOD/HANCOCK PARK ADJ)', ' (North Westlake)',
#        ' (5200 Wilshire)', ' (los angeles)', ' (Little Tokyo)',
#        ' (42nd & Central)', ' (Eugene St,Los Angeles, CA.)',
#        ' (WILLOWBROOK)', ' (North Hollywood)', ' (Atwater Village)',
#        ' (Studio City)', ' (GLENDALE or CLOSE BY)',
#        ' (930 Figuroa Terrace, Los Angeles, CA)',
#        ' (616 St. Paul Ave., Los Angeles, CA)', ' (Beverly Hills)',
#        ' (616 St. Paul Ave. , Los Angeles, CA)',
#        ' (4077 West 3rd Street , Los Angeles, CA)',
#        ' (5119 Maplewood Ave, Los Angeles, CA)', ' (Vernon)',
#        ' (2711 Ellendale Place, Los Angeles, CA)', ' (611 N Howard St)',
#        ' (Downtown Los Angeles)', ' (Koreatown/Downtown LA)',
#        ' (5015 Clinton Street, Los Angeles, CA)',
#        ' (Los Angeles / Koreatown)'], dtype=object)

# %% [markdown]
# What about the relationship between prices and the apartment size?

# %%
df.plot('sq_ft', 'price_numeric', kind='scatter')
# Out:
# <AxesSubplot:xlabel='sq_ft', ylabel='price_numeric'>

# %% [markdown]
# So now we've created a dataframe that extracts all the posts on the first page!
#
# There's still quite a bit to do. For example:
#
# * We only have one page, and it would be useful to get data from the subsequent pages
# * Our neighborhood field is really dirty, so it's hard to do any mapping
# * We don't have any information about parking
# * We don't have the geographic coordinates (lat/lon)
#
# But let's leave those for future work.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Key Takeaways</h3>
# <ul>
#   <li>Scraping unstructured webpages involves more detective work and trial and error.</li>
#   <li>Some will have a consistent format and helpful class codes and html tags. Some won't.</li>
#   <li>Your code will need to be robust to missing fields and other inconsistencies in page formatting.</li>
#   <li>Be nice! You may need to slow the pace of your requests down.</li>
# </ul>
# </div>
